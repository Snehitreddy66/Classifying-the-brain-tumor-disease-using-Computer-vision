# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2

from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
# from keras.layers.normalization import BatchNormalization
import os
import seaborn as sns
from keras.layers.core import Activation, Flatten, Dropout, Dense

# %%
pwd
# Out:
# 'C:\\Users\\SNEHIT REDDY\\Desktop\\Brain Tumor'

# %%
print(os.listdir("C:\\Users\\SNEHIT REDDY\\Desktop\\Brain Tumor\\Brain tumor Dataset\\"))
# Out:
# ['.ipynb_checkpoints', 'raw.githubusercontent.com_rohan-paul_MachineLearning-DeepLearning-Code-for-my-YouTube-Channel_master_Computer_Vision_Unet-Brain-MRI-Segmentation-Tensorflow-Keras_Unet-Brain-MRI-Segmentation.ipynb', 'train', 'val']

# %%
SIZE = 224

# %%
train_images = []
train_labels = [] 
for directory_path in glob.glob("C:\\Users\\SNEHIT REDDY\\Desktop\\Brain Tumor\\Brain tumor Dataset\\train\\*"):
    label = directory_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_images.append(img)
        train_labels.append(label)
        
train_images = np.array(train_images)
train_labels = np.array(train_labels)
# Out:
# Glioma
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\0.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\10.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\100.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\101.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\102.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\103.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\104.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\105.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\106.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\107.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1073.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1074.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1075.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1076.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1077.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1078.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1079.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\108.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1080.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1083.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1084.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1085.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1086.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1087.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1089.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\109.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1090.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1091.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1092.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1093.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1094.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1095.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1096.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1099.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\11.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\110.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1100.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1101.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1102.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1103.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1104.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1105.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1106.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1107.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1108.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1109.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1110.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1111.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1112.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1113.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1114.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1115.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1116.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1117.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1118.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1119.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\112.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1120.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1121.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1122.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1123.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1124.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1125.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1126.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1127.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1128.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1129.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\113.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1130.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1131.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1132.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1133.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1134.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1135.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1136.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1137.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1138.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1139.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\114.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1140.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1141.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1142.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1144.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1146.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1147.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1148.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\115.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1150.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1151.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1152.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1153.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1154.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1155.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1156.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1157.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1159.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\116.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1160.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1161.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1162.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1165.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1166.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1167.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1169.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\117.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1170.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1171.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1172.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1174.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1175.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1176.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1177.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1178.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1179.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\118.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1180.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1181.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1182.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1183.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1184.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1186.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1187.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\119.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1190.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1192.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1193.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1194.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1195.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1196.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1197.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1199.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\12.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\120.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1200.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1201.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1202.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1203.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1204.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1205.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1206.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1207.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1208.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\121.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1210.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1211.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1212.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1213.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1214.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1215.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1216.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1217.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1218.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1219.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\122.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1220.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1221.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1222.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1223.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1224.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1225.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1226.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1227.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1228.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1229.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\123.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1230.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1231.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1232.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1233.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1234.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1235.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1236.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1237.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1238.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1239.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\124.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1240.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1241.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1242.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1243.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1244.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1245.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1246.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1247.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1248.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1249.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\125.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1250.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1251.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1252.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1253.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1254.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1255.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1256.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1257.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1259.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\126.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1260.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1261.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1262.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1263.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1264.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1265.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1267.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1268.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1269.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\127.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1270.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1271.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1272.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1273.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1274.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1275.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1276.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1277.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1278.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1279.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\128.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1280.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1281.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1282.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1284.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1285.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1286.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1287.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1288.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1289.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\129.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1290.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1291.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1292.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1293.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1294.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1295.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1296.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1297.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1298.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1299.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\13.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\130.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1300.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1301.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1302.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1303.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1304.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1306.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1307.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1308.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1309.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\131.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1310.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1311.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1312.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1313.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1314.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1316.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1317.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1318.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1319.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\132.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1320.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1321.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1322.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1323.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1324.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1325.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1326.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\1327.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Glioma\
png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8280.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8289.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8293.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_83.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8317.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_832.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8324.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8402.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_841.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8411.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8436.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8440.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8460.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8467.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_848.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8517.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8519.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8530.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8533.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8534.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8545.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8546.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8594.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8604.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8617.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8637.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8643.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_866.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8660.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_867.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8676.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8686.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8688.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8695.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8721.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8733.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8750.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8769.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8771.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8776.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8788.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8796.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_880.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8809.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8829.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8839.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8850.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8851.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8857.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8873.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8874.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8881.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8904.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8935.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8937.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8955.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8979.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8985.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8986.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_8991.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9012.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9015.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9032.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9042.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9047.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9079.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9082.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9106.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9108.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9122.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9134.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_9136.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_930.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_94.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_951.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_973.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_980.png
# C:\Users\SNEHIT REDDY\Desktop\Brain Tumor\Brain tumor Dataset\train\Pituitary Tumor\aug_0_986.png

# %%
# test
test_images = []
test_labels = [] 
for directory_path in glob.glob("C:\\Users\\SNEHIT REDDY\\Desktop\\Brain Tumor\\Brain tumor Dataset\\val\\*"):
    fruit_label = directory_path.split("\\")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.png")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# %%
x_train.shape, y_train.shape
# Out:
# ((4500, 224, 224, 3), (4500,))

# %%
x_test.shape, y_test.shape
# Out:
# ((450, 224, 224, 3), (450,))

# %%
# Normalize pixel values to between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
#One hot encode y values for neural network. 
from keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
from tensorflow.keras.layers import Input, Conv2D, \
     BatchNormalization, MaxPool2D, Flatten, Dense, Dropout, AveragePooling2D

# %% [markdown]
# # AlexNet

# %%
feature_extractor = Sequential()
input = Input(shape=(224, 224, 3))

feature_extractor = Conv2D(filters=96,
           kernel_size=11,
           strides=4,
           padding = 'same',
           activation='relu')(input)  # 1st convolutional layer
feature_extractor = BatchNormalization()(feature_extractor)
feature_extractor = MaxPool2D(pool_size=3, strides=2)(feature_extractor)    # pooling Layer 1

feature_extractor = Conv2D(filters=256,
           kernel_size=5,
           strides=1,
           activation='relu')(feature_extractor)  # 2nd convolutional layer
feature_extractor = BatchNormalization()(feature_extractor)
feature_extractor = MaxPool2D(pool_size=3, strides=2)(feature_extractor)  # pooling layer 2

feature_extractor = Conv2D(filters=384,
           kernel_size=3,
           strides=1,
           activation='relu')(feature_extractor)  # 3rd convolutional layer

feature_extractor = Conv2D(filters=384,
           kernel_size=3,
           strides=1,
           activation='relu')(feature_extractor)

feature_extractor = Conv2D(filters=384,
           kernel_size=3,
           strides=1,
           activation='relu')(feature_extractor)

feature_extractor = BatchNormalization()(feature_extractor)
feature_extractor = MaxPool2D(pool_size=3, strides=2)(feature_extractor)

# %%
feature_extractor = Flatten()(feature_extractor)

# %%
#x = Flatten()(feature_extractor)
x = Dense(units=4096, activation='relu')(feature_extractor)
x = Dense(units=4096, activation='relu')(x)
x = Dropout(rate=0.5)(x)

# %%
x.shape
# Out:
# TensorShape([None, 4096])

# %%
output = Dense(units=3, activation='softmax')(x)

# %%
from tensorflow.keras import Model

model = Model(inputs=input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 56, 56, 96)        34944
#
#  batch_normalization (BatchN  (None, 56, 56, 96)       384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 23, 23, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 23, 23, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 11, 11, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 384)         885120
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 384)         1327488
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 384)         1327488
#
#  batch_normalization_2 (Batc  (None, 5, 5, 384)        1536
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 384)        0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 4096)              6295552
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 27,281,795
# Trainable params: 27,280,323
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
import keras

# %%
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
from keras import optimizers
sgd = optimizers.SGD(learning_rate=0.1, decay=1e-6, momentum=0.9)
print("[INFO] training network...")
model.compile(loss="categorical_crossentropy", optimizer=sgd,metrics=["accuracy"])
# Out:
# [INFO] training network...

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping()

# %%
custom_early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    min_delta=0.1, 
    mode='min'
)

# %%
256*2
# Out:
# 512

# %%
x_train.shape, y_train_one_hot.shape
# Out:
# ((4500, 224, 224, 3), (4500, 3))

# %%
import datetime
start = datetime.datetime.now()
#Fit the model. Do not forget to use on-hot-encoded Y values. 
history=model.fit(x_train, y_train_one_hot, batch_size=128,epochs=10, validation_data=(x_test, y_test_one_hot),callbacks=[custom_early_stopping])

end = datetime.datetime.now()
print("Total execution time : ", end-start)
# Out:
# Epoch 1/10
# 36/36 [==============================] - 135s 4s/step - loss: nan - accuracy: 0.3384 - val_loss: nan - val_accuracy: 0.3333
# Epoch 2/10
# 36/36 [==============================] - 140s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 3/10
# 36/36 [==============================] - 138s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 4/10
# 36/36 [==============================] - 145s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Epoch 5/10
# 36/36 [==============================] - 140s 4s/step - loss: nan - accuracy: 0.3333 - val_loss: nan - val_accuracy: 0.3333
# Total execution time :  0:11:41.858660

# %%
feature_extractor=model.predict(x_train)
# Out:
# 141/141 [==============================] - 46s 321ms/step

# %%
features = feature_extractor.reshape(feature_extractor.shape[0], -1)

# %%
X_for_training = features #This is our X input to ML

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_train, y_train_one_hot)
print("Train Loss = " +str(scores[0]))
print("Train Accuracy = " + str(scores[1]*100))
# Out:
# [INFO] Calculating model accuracy
# 141/141 [==============================] - 36s 252ms/step - loss: nan - accuracy: 0.3333
# Train Loss = nan
# Train Accuracy = 33.33333432674408

# %%
scores = model.evaluate(x_test, y_test_one_hot)
print("Test Loss = " +str(scores[0]))
print("Tesst Accuracy = " + str(scores[1]*100))
# Out:
# 15/15 [==============================] - 4s 249ms/step - loss: nan - accuracy: 0.3333
# Test Loss = nan
# Tesst Accuracy = 33.33333432674408

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.grid()
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'g', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
#plt.grid()
plt.legend()
plt.show()

# %%
##Predict on test dataset
predict_test = model.predict(x_test)
predict_test = np.argmax(predict_test, axis=1)
predict_test = le.inverse_transform(predict_test)
print("Predicted test data shape is:",predict_test.shape)
# Out:
# 15/15 [==============================] - 4s 227ms/step
# Predicted test data shape is: (450,)

# %%
##Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predict_test)*100)
# Out:
# Accuracy =  33.33333333333333

# %%
print("Correct Predictions are :",sum(test_labels== predict_test))
print("In Correct Predictions are :",sum(test_labels != predict_test))
print("Accuracy :",sum(test_labels== predict_test)/len(predict_test)*100)
# Out:
# Correct Predictions are : 150
# In Correct Predictions are : 300
# Accuracy : 33.33333333333333

# %%
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predict_test)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# [[150   0   0]
#  [150   0   0]
#  [150   0   0]]
# <AxesSubplot:>

# %%
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import classification_report

print("Classification report: \n",classification_report(test_labels, predict_test,digits=4))
# Out:
# Classification report:
#                   precision    recall  f1-score   support
#
#          Glioma     0.3333    1.0000    0.5000       150
#      Meningioma     0.0000    0.0000    0.0000       150
# Pituitary Tumor     0.0000    0.0000    0.0000       150
#
#        accuracy                         0.3333       450
#       macro avg     0.1111    0.3333    0.1667       450
#    weighted avg     0.1111    0.3333    0.1667       450
# C:\Users\SNEHIT REDDY\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SNEHIT REDDY\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\SNEHIT REDDY\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(X_for_training)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 pca = PCA().fit(X_for_training)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:456, in PCA._fit(self, X)
#     450 if issparse(X):
#     451     raise TypeError(
#     452         "PCA does not support sparse input. See "
#     453         "TruncatedSVD for a possible alternative."
#     454     )
# --> 456 X = self._validate_data(
#     457     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     458 )
#     460 # Handle n_components==None
#     461 if self.n_components is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.
# PCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
imp.fit(X_for_training)
# Out:
# SimpleImputer()

# %%
pca = PCA().fit(X_for_training)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 pca = PCA().fit(X_for_training)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:456, in PCA._fit(self, X)
#     450 if issparse(X):
#     451     raise TypeError(
#     452         "PCA does not support sparse input. See "
#     453         "TruncatedSVD for a possible alternative."
#     454     )
# --> 456 X = self._validate_data(
#     457     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     458 )
#     460 # Handle n_components==None
#     461 if self.n_components is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.
# PCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
import pandas as pd

# %%
pd.DataFrame(X_for_training)
# Out:
#        0   1   2
# 0    NaN NaN NaN
# 1    NaN NaN NaN
# 2    NaN NaN NaN
# 3    NaN NaN NaN
# 4    NaN NaN NaN
# ...   ..  ..  ..
# 4495 NaN NaN NaN
# 4496 NaN NaN NaN
# 4497 NaN NaN NaN
# 4498 NaN NaN NaN
# 4499 NaN NaN NaN
#
# [4500 rows x 3 columns]

# %%
train_loss, train_acc = model.evaluate(directory_path(train_images), encode_label(train_labels))
test_loss, test_acc = model.evaluate(directory_path(test_images), encode_label(test_labelst))

print('Train accuracy:', train_acc)
print('Test accuracy:', test_acc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 train_loss, train_acc = model.evaluate(directory_path(train_images), encode_label(train_labels))
#       2 test_loss, test_acc = model.evaluate(directory_path(test_images), encode_label(test_labelst))
#       4 print('Train accuracy:', train_acc)
#
# TypeError: 'str' object is not callable
